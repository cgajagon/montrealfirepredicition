# %%
import pandas as pd

import numpy as np

from sklearn.model_selection import TimeSeriesSplit, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score

import pickle

import json

import matplotlib.pyplot as plt

import folium
from folium.plugins import HeatMap

# %%
# %load_ext kedro.ipython
table = catalog.load("input_table")
# Out:
# [07/08/24 14:35:22] INFO     Registered line magic '%reload_kedro'                                   ]8;id=44111;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=634537;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=533776;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=187739;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py#60\60]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=979580;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=44186;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py#171\171]8;;\
#                              c:\Users\carga\Documents\KedroTutorial\montrealfirepredicition.
#                              To set a different path, run '%reload_kedro <project_root>'
# [07/08/24 14:35:24] WARNING  C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:109
#                              3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\ked
#                              ro_viz\integrations\kedro\hooks.py:13: KedroDeprecationWarning:
#                              'TRANSCODING_SEPARATOR' has been moved to
#                              'kedro.pipeline.transcoding', and the alias will be removed in Kedro
#                              0.20.0
#                                from kedro.pipeline.pipeline import TRANSCODING_SEPARATOR,
#                              _strip_transcoding
#                     WARNING  C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:109
#                              3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\laz
#                              y_loader\__init__.py:83: KedroDeprecationWarning: 'GeoJSONDataSet' has
#                              been renamed to 'GeoJSONDataset', and the alias will be removed in
#                              Kedro-Datasets 2.0.0
#                                attr = getattr(submod, name)
# [07/08/24 14:35:25] INFO     Kedro project montrealfirepredicition                                  ]8;id=310964;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=428400;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py#141\141]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=554878;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=148098;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py#142\142]8;;\
#                              'pipelines'
#                     WARNING  C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:109
#                              3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\ked
#                              ro_viz\models\flowchart.py:13: KedroDeprecationWarning:
#                              'TRANSCODING_SEPARATOR' has been moved to
#                              'kedro.pipeline.transcoding', and the alias will be removed in Kedro
#                              0.20.0
#                                from kedro.pipeline.pipeline import TRANSCODING_SEPARATOR,
#                              _strip_transcoding
#                     WARNING  C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:109
#                              3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\ked
#                              ro_viz\data_access\repositories\catalog.py:8: KedroDeprecationWarning:
#                              'TRANSCODING_SEPARATOR' has been moved to
#                              'kedro.pipeline.transcoding', and the alias will be removed in Kedro
#                              0.20.0
#                                from kedro.pipeline.pipeline import TRANSCODING_SEPARATOR,
#                              _strip_transcoding
# [07/08/24 14:35:26] INFO     Registered line magic 'run_viz'                                        ]8;id=905950;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=849108;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\ipython\__init__.py#148\148]8;;\
#                     INFO     Loading data from input_table (CSVDataset)...                      ]8;id=114442;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=6963;file://C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\kedro\io\data_catalog.py#508\508]8;;\
# [07/08/24 14:35:38] WARNING  C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python. warnings.py:109
#                              3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\ked
#                              ro_datasets\pandas\csv_dataset.py:163: DtypeWarning: Columns
#                              (1,2,5,6,11,21,22,25) have mixed types. Specify dtype option on import
#                              or set low_memory=False.
#                                return pd.read_csv(load_path, **self._load_args)

# %%
# Path to the pickle file
pickle_file_path = 'C://Users//carga//Documents//KedroTutorial//montrealfirepredicition//data//07_model_output//trained_time_series_xgb_model_3months_v2.pkl'

# Open the pickle file and load the model
with open(pickle_file_path, 'rb') as file:
    model = pickle.load(file)

# %%
def get_mode(series):
    mode = series.mode()
    if not mode.empty:
        return mode.iloc[0]
    else:
        return None  # or a default value like 'unknown'

# %%
# Group by grid location and month
aggregated_data = pd.DataFrame()
aggregated_data = table.groupby(['grid_lat', 'grid_long', 'year', 'month']).agg({
    'index_mesh': 'first',
    'USE_CATEGORY': get_mode,
    'YEAR_CONSTRUCTION': 'mean',
    'is_fire': 'sum',  # Sum to count number of fire incidents
    'ABOVE_GROUND_FLOORS': 'max',
    'HOUSING_UNITS': 'mean',
    'distance_to_fire_station': 'mean',
    'building_age': 'mean',
    'AVERAGE_FAMILY_SIZE': 'mean',
    'POPULATION_DENSITY': 'mean',
    '2021_POPULATION': 'mean',
    'time_of_day': get_mode,
    'day_of_week': get_mode,
    'INCIDENT_ID': 'count',
}).reset_index()

# Fill missing categorical values with 'missing' and numerical with the mean
categorical_features = ['time_of_day', 'day_of_week', 'USE_CATEGORY']
numerical_features = ['grid_lat', 'grid_long', 'ABOVE_GROUND_FLOORS', 'YEAR_CONSTRUCTION', 'HOUSING_UNITS', 'building_age', 'distance_to_fire_station', 'AVERAGE_FAMILY_SIZE', 'POPULATION_DENSITY', '2021_POPULATION', 'INCIDENT_ID']

for col in categorical_features:
    aggregated_data[col].fillna('missing', inplace=True)

for col in numerical_features:
    aggregated_data[col].fillna(aggregated_data[col].mean(), inplace=True)

# %%
aggregated_data[aggregated_data['index_mesh'] == 82]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       grid_lat  grid_long    year  month  index_mesh USE_CATEGORY  \
# 0    45.403963 -73.946646  2005.0    1.0          82      missing
# 1    45.403963 -73.946646  2005.0    2.0          82      missing
# 2    45.403963 -73.946646  2005.0    3.0          82      missing
# 3    45.403963 -73.946646  2005.0    4.0          82      missing
# 4    45.403963 -73.946646  2005.0    5.0          82      missing
# ..         ...        ...     ...    ...         ...          ...
# 159  45.403963 -73.946646  2023.0    8.0          82      missing
# 160  45.403963 -73.946646  2023.0    9.0          82      missing
# 161  45.403963 -73.946646  2023.0   10.0          82      missing
# 162  45.403963 -73.946646  2023.0   11.0          82      missing
# 163  45.403963 -73.946646  2023.0   12.0          82      missing
#
#      YEAR_CONSTRUCTION  is_fire  ABOVE_GROUND_FLOORS  HOUSING_UNITS  \
# 0                  NaN        0                  NaN            NaN
# 1                  NaN        1                  NaN            NaN
# 2                  NaN        0                  NaN            NaN
# 3                  NaN        1                  NaN            NaN
# 4                  NaN        2                  NaN            NaN
# ..                 ...      ...                  ...            ...
# 159                NaN        0                  NaN            NaN
# 160                NaN        0                  NaN            NaN
# 161                NaN        0                  NaN            NaN
# 162                NaN        0                  NaN            NaN
# 163                NaN        0                  NaN            NaN
#
#      distance_to_fire_station  building_age  AVERAGE_FAMILY_SIZE  \
# 0                    1.558668           NaN                  NaN
# 1                    1.558668           NaN                  NaN
# 2                    1.558668           NaN                  NaN
# 3                    1.558668           NaN                  NaN
# 4                    1.558668           NaN                  NaN
# ..                        ...           ...                  ...
# 159                  1.558668           NaN                  NaN
# 160                  1.558668           NaN                  NaN
# 161                  1.558668           NaN                  NaN
# 162                  1.558668           NaN                  NaN
# 163                  1.558668           NaN                  NaN
#
#      POPULATION_DENSITY  2021_POPULATION time_of_day  day_of_week  INCIDENT_ID
# 0                   NaN              NaN     evening          2.0            1
# 1                   NaN              NaN     evening          1.0            2
# 2                   NaN              NaN       night          1.0            1
# 3                   NaN              NaN       night          1.0            1
# 4                   NaN              NaN     evening          6.0            3
# ..                  ...              ...         ...          ...          ...
# 159                 NaN              NaN     evening          1.0            1
# 160                 NaN              NaN     morning          4.0            2
# 161                 NaN              NaN     evening          0.0            5
# 162                 NaN              NaN   afternoon          0.0            2
# 163                 NaN              NaN     evening          6.0            1
#
# [164 rows x 18 columns]

# %%
# Create lag features for previous months
# Number of lags to create
n_lags = 3

merged_aggregated_data = pd.DataFrame()
merged_aggregated_data = aggregated_data.copy()

# %%
merged_aggregated_data.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['grid_lat', 'grid_long', 'year', 'month', 'index_mesh', 'USE_CATEGORY',
#        'YEAR_CONSTRUCTION', 'is_fire', 'ABOVE_GROUND_FLOORS', 'HOUSING_UNITS',
#        'distance_to_fire_station', 'building_age', 'AVERAGE_FAMILY_SIZE',
#        'POPULATION_DENSITY', '2021_POPULATION', 'time_of_day', 'day_of_week',
#        'INCIDENT_ID'],
#       dtype='object')

# %%
# Create lag features for previous months
# Number of lags to create
n_lags = 3

merged_aggregated_data = pd.DataFrame()
merged_aggregated_data = aggregated_data.copy()

# Loop to create lag features
for lag in range(1, n_lags + 1):
    # Copy the original data
    lagged_features = aggregated_data.copy()

    # Shift the month by the current lag value
    lagged_features['month'] = (lagged_features['month'] - lag - 1) % 12 + 1

    # Rename columns to indicate the lag
    lagged_features.columns = [
        col + f'_lag{lag}' if col not in ['index_mesh','grid_lat', 'grid_long', 'year', 'month'] else col
        for col in lagged_features.columns
    ]

    # Merge lagged features back into the original data
    merged_aggregated_data = pd.merge(
        merged_aggregated_data, lagged_features,
        on=['index_mesh','grid_lat', 'grid_long', 'year', 'month'],
        how='left'
    )

# %%
merged_aggregated_data.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['grid_lat', 'grid_long', 'year', 'month', 'index_mesh', 'USE_CATEGORY',
#        'YEAR_CONSTRUCTION', 'is_fire', 'ABOVE_GROUND_FLOORS', 'HOUSING_UNITS',
#        'distance_to_fire_station', 'building_age', 'AVERAGE_FAMILY_SIZE',
#        'POPULATION_DENSITY', '2021_POPULATION', 'time_of_day', 'day_of_week',
#        'INCIDENT_ID', 'USE_CATEGORY_lag1', 'YEAR_CONSTRUCTION_lag1',
#        'is_fire_lag1', 'ABOVE_GROUND_FLOORS_lag1', 'HOUSING_UNITS_lag1',
#        'distance_to_fire_station_lag1', 'building_age_lag1',
#        'AVERAGE_FAMILY_SIZE_lag1', 'POPULATION_DENSITY_lag1',
#        '2021_POPULATION_lag1', 'time_of_day_lag1', 'day_of_week_lag1',
#        'INCIDENT_ID_lag1', 'USE_CATEGORY_lag2', 'YEAR_CONSTRUCTION_lag2',
#        'is_fire_lag2', 'ABOVE_GROUND_FLOORS_lag2', 'HOUSING_UNITS_lag2',
#        'distance_to_fire_station_lag2', 'building_age_lag2',
#        'AVERAGE_FAMILY_SIZE_lag2', 'POPULATION_DENSITY_lag2',
#        '2021_POPULATION_lag2', 'time_of_day_lag2', 'day_of_week_lag2',
#        'INCIDENT_ID_lag2', 'USE_CATEGORY_lag3', 'YEAR_CONSTRUCTION_lag3',
#        'is_fire_lag3', 'ABOVE_GROUND_FLOORS_lag3', 'HOUSING_UNITS_lag3',
#        'distance_to_fire_station_lag3', 'building_age_lag3',
#        'AVERAGE_FAMILY_SIZE_lag3', 'POPULATION_DENSITY_lag3',
#        '2021_POPULATION_lag3', 'time_of_day_lag3', 'day_of_week_lag3',
#        'INCIDENT_ID_lag3'],
#       dtype='object')

# %%
merged_aggregated_data[['index_mesh','grid_lat', 'grid_long', 'year', 'month','distance_to_fire_station', 'distance_to_fire_station_lag1']][merged_aggregated_data['index_mesh'] == 82]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      index_mesh   grid_lat  grid_long    year  month  \
# 0            82  45.403963 -73.946646  2005.0    1.0
# 1            82  45.403963 -73.946646  2005.0    2.0
# 2            82  45.403963 -73.946646  2005.0    3.0
# 3            82  45.403963 -73.946646  2005.0    4.0
# 4            82  45.403963 -73.946646  2005.0    5.0
# ..          ...        ...        ...     ...    ...
# 159          82  45.403963 -73.946646  2023.0    8.0
# 160          82  45.403963 -73.946646  2023.0    9.0
# 161          82  45.403963 -73.946646  2023.0   10.0
# 162          82  45.403963 -73.946646  2023.0   11.0
# 163          82  45.403963 -73.946646  2023.0   12.0
#
#      distance_to_fire_station  distance_to_fire_station_lag1
# 0                    1.558668                       1.558668
# 1                    1.558668                       1.558668
# 2                    1.558668                       1.558668
# 3                    1.558668                       1.558668
# 4                    1.558668                            NaN
# ..                        ...                            ...
# 159                  1.558668                       1.558668
# 160                  1.558668                       1.558668
# 161                  1.558668                       1.558668
# 162                  1.558668                       1.558668
# 163                  1.558668                       1.558668
#
# [164 rows x 7 columns]

# %%
# Ensure all data types are correctly set for the pipeline
for col in categorical_features:
    merged_aggregated_data[col] = merged_aggregated_data[col].astype(str)

# Shift the target variable to the previous month to predict the next month's fire
merged_aggregated_data['is_fire'] = merged_aggregated_data.groupby(['grid_lat', 'grid_long'])['is_fire'].shift(-1)

# Drop rows with missing target
merged_aggregated_data.dropna(subset=['is_fire'], inplace=True)

# Convert 'is_fire' to a binary numerical column for classification purposes (e.g., threshold at 0.5)
merged_aggregated_data['is_fire'] = (merged_aggregated_data['is_fire'] > 0.5).astype(int)

# %%
# Prepare the data
features = [col for col in merged_aggregated_data.columns if col not in ['is_fire', 'year', 'month']]
X = merged_aggregated_data[features]
y = merged_aggregated_data['is_fire']

# %%
# Make predictions
merged_aggregated_data['predicted_fire'] = model.predict(X)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 # Make predictions                                                                           │
# │ ❱ 2 merged_aggregated_data['predicted_fire'] = model.predict(X)                                  │
# │   3                                                                                              │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\imblearn\pipeline.py:459 in predict                     │
# │                                                                                                  │
# │    456 │   │                                                                                     │
# │    457 │   │   if not _routing_enabled():                                                        │
# │    458 │   │   │   for _, name, transform in self._iter(with_final=False):                       │
# │ ❱  459 │   │   │   │   Xt = transform.transform(Xt)                                              │
# │    460 │   │   │   return self.steps[-1][1].predict(Xt, **params)                                │
# │    461 │   │                                                                                     │
# │    462 │   │   # metadata routing enabled                                                        │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\utils\_set_output.py:140 in wrapped             │
# │                                                                                                  │
# │   137 │                                                                                          │
# │   138 │   @wraps(f)                                                                              │
# │   139 │   def wrapped(self, X, *args, **kwargs):                                                 │
# │ ❱ 140 │   │   data_to_wrap = f(self, X, *args, **kwargs)                                         │
# │   141 │   │   if isinstance(data_to_wrap, tuple):                                                │
# │   142 │   │   │   # only wrap the first output for cross decomposition                           │
# │   143 │   │   │   return (                                                                       │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\compose\_column_transformer.py:800 in transform │
# │                                                                                                  │
# │    797 │   │   │   # check that n_features_in_ is consistent                                     │
# │    798 │   │   │   self._check_n_features(X, reset=False)                                        │
# │    799 │   │                                                                                     │
# │ ❱  800 │   │   Xs = self._fit_transform(                                                         │
# │    801 │   │   │   X,                                                                            │
# │    802 │   │   │   None,                                                                         │
# │    803 │   │   │   _transform_one,                                                               │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\compose\_column_transformer.py:658 in           │
# │ _fit_transform                                                                                   │
# │                                                                                                  │
# │    655 │   │   │   )                                                                             │
# │    656 │   │   )                                                                                 │
# │    657 │   │   try:                                                                              │
# │ ❱  658 │   │   │   return Parallel(n_jobs=self.n_jobs)(                                          │
# │    659 │   │   │   │   delayed(func)(                                                            │
# │    660 │   │   │   │   │   transformer=clone(trans) if not fitted else trans,                    │
# │    661 │   │   │   │   │   X=_safe_indexing(X, column, axis=1),                                  │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\utils\parallel.py:63 in __call__                │
# │                                                                                                  │
# │    60 │   │   │   (_with_config(delayed_func, config), args, kwargs)                             │
# │    61 │   │   │   for delayed_func, args, kwargs in iterable                                     │
# │    62 │   │   )                                                                                  │
# │ ❱  63 │   │   return super().__call__(iterable_with_config)                                      │
# │    64                                                                                            │
# │    65                                                                                            │
# │    66 # remove when https://github.com/joblib/joblib/issues/1071 is fixed                        │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\joblib\parallel.py:1918 in __call__                     │
# │                                                                                                  │
# │   1915 │   │   │   # immediately to avoid overheads.                                             │
# │   1916 │   │   │   output = self._get_sequential_output(iterable)                                │
# │   1917 │   │   │   next(output)                                                                  │
# │ ❱ 1918 │   │   │   return output if self.return_generator else list(output)                      │
# │   1919 │   │                                                                                     │
# │   1920 │   │   # Let's create an ID that uniquely identifies the current call. If the            │
# │   1921 │   │   # call is interrupted early and that the same instance is immediately             │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\joblib\parallel.py:1844 in _get_sequential_output       │
# │                                                                                                  │
# │   1841 │   │   │   yield None                                                                    │
# │   1842 │   │   │                                                                                 │
# │   1843 │   │   │   # Sequentially call the tasks and yield the results.                          │
# │ ❱ 1844 │   │   │   for func, args, kwargs in iterable:                                           │
# │   1845 │   │   │   │   self.n_dispatched_batches += 1                                            │
# │   1846 │   │   │   │   self.n_dispatched_tasks += 1                                              │
# │   1847 │   │   │   │   res = func(*args, **kwargs)                                               │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\utils\parallel.py:59 in <genexpr>               │
# │                                                                                                  │
# │    56 │   │   # in a different thread depending on the backend and on the value of               │
# │    57 │   │   # pre_dispatch and n_jobs.                                                         │
# │    58 │   │   config = get_config()                                                              │
# │ ❱  59 │   │   iterable_with_config = (                                                           │
# │    60 │   │   │   (_with_config(delayed_func, config), args, kwargs)                             │
# │    61 │   │   │   for delayed_func, args, kwargs in iterable                                     │
# │    62 │   │   )                                                                                  │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\compose\_column_transformer.py:661 in <genexpr> │
# │                                                                                                  │
# │    658 │   │   │   return Parallel(n_jobs=self.n_jobs)(                                          │
# │    659 │   │   │   │   delayed(func)(                                                            │
# │    660 │   │   │   │   │   transformer=clone(trans) if not fitted else trans,                    │
# │ ❱  661 │   │   │   │   │   X=_safe_indexing(X, column, axis=1),                                  │
# │    662 │   │   │   │   │   y=y,                                                                  │
# │    663 │   │   │   │   │   weight=weight,                                                        │
# │    664 │   │   │   │   │   message_clsname="ColumnTransformer",                                  │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\utils\__init__.py:354 in _safe_indexing         │
# │                                                                                                  │
# │    351 │   │   )                                                                                 │
# │    352 │                                                                                         │
# │    353 │   if hasattr(X, "iloc"):                                                                │
# │ ❱  354 │   │   return _pandas_indexing(X, indices, indices_dtype, axis=axis)                     │
# │    355 │   elif hasattr(X, "shape"):                                                             │
# │    356 │   │   return _array_indexing(X, indices, indices_dtype, axis=axis)                      │
# │    357 │   else:                                                                                 │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\sklearn\utils\__init__.py:200 in _pandas_indexing       │
# │                                                                                                  │
# │    197 │   else:                                                                                 │
# │    198 │   │   # check whether we should index with loc or iloc                                  │
# │    199 │   │   indexer = X.iloc if key_dtype == "int" else X.loc                                 │
# │ ❱  200 │   │   return indexer[:, key] if axis else indexer[key]                                  │
# │    201                                                                                           │
# │    202                                                                                           │
# │    203 def _list_indexing(X, key, key_dtype):                                                    │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexing.py:1097 in __getitem__             │
# │                                                                                                  │
# │   1094 │   │   │   key = tuple(com.apply_if_callable(x, self.obj) for x in key)                  │
# │   1095 │   │   │   if self._is_scalar_access(key):                                               │
# │   1096 │   │   │   │   return self.obj._get_value(*key, takeable=self._takeable)                 │
# │ ❱ 1097 │   │   │   return self._getitem_tuple(key)                                               │
# │   1098 │   │   else:                                                                             │
# │   1099 │   │   │   # we by definition only have the 0th axis                                     │
# │   1100 │   │   │   axis = self.axis or 0                                                         │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexing.py:1289 in _getitem_tuple          │
# │                                                                                                  │
# │   1286 │   │   if self._multi_take_opportunity(tup):                                             │
# │   1287 │   │   │   return self._multi_take(tup)                                                  │
# │   1288 │   │                                                                                     │
# │ ❱ 1289 │   │   return self._getitem_tuple_same_dim(tup)                                          │
# │   1290 │                                                                                         │
# │   1291 │   def _get_label(self, label, axis: AxisInt):                                           │
# │   1292 │   │   # GH#5567 this will fail if the label is not present in the axis.                 │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexing.py:955 in _getitem_tuple_same_dim  │
# │                                                                                                  │
# │    952 │   │   │   if com.is_null_slice(key):                                                    │
# │    953 │   │   │   │   continue                                                                  │
# │    954 │   │   │                                                                                 │
# │ ❱  955 │   │   │   retval = getattr(retval, self.name)._getitem_axis(key, axis=i)                │
# │    956 │   │   │   # We should never have retval.ndim < self.ndim, as that should                │
# │    957 │   │   │   #  be handled by the _getitem_lowerdim call above.                            │
# │    958 │   │   │   assert retval.ndim == self.ndim                                               │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexing.py:1332 in _getitem_axis           │
# │                                                                                                  │
# │   1329 │   │   │   │   if hasattr(key, "ndim") and key.ndim > 1:                                 │
# │   1330 │   │   │   │   │   raise ValueError("Cannot index with multidimensional key")            │
# │   1331 │   │   │   │                                                                             │
# │ ❱ 1332 │   │   │   │   return self._getitem_iterable(key, axis=axis)                             │
# │   1333 │   │   │                                                                                 │
# │   1334 │   │   │   # nested tuple slicing                                                        │
# │   1335 │   │   │   if is_nested_tuple(key, labels):                                              │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexing.py:1272 in _getitem_iterable       │
# │                                                                                                  │
# │   1269 │   │   self._validate_key(key, axis)                                                     │
# │   1270 │   │                                                                                     │
# │   1271 │   │   # A collection of keys                                                            │
# │ ❱ 1272 │   │   keyarr, indexer = self._get_listlike_indexer(key, axis)                           │
# │   1273 │   │   return self.obj._reindex_with_indexers(                                           │
# │   1274 │   │   │   {axis: [keyarr, indexer]}, copy=True, allow_dups=True                         │
# │   1275 │   │   )                                                                                 │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexing.py:1462 in _get_listlike_indexer   │
# │                                                                                                  │
# │   1459 │   │   ax = self.obj._get_axis(axis)                                                     │
# │   1460 │   │   axis_name = self.obj._get_axis_name(axis)                                         │
# │   1461 │   │                                                                                     │
# │ ❱ 1462 │   │   keyarr, indexer = ax._get_indexer_strict(key, axis_name)                          │
# │   1463 │   │                                                                                     │
# │   1464 │   │   return keyarr, indexer                                                            │
# │   1465                                                                                           │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexes\base.py:5877 in _get_indexer_strict │
# │                                                                                                  │
# │   5874 │   │   else:                                                                             │
# │   5875 │   │   │   keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)               │
# │   5876 │   │                                                                                     │
# │ ❱ 5877 │   │   self._raise_if_missing(keyarr, indexer, axis_name)                                │
# │   5878 │   │                                                                                     │
# │   5879 │   │   keyarr = self.take(indexer)                                                       │
# │   5880 │   │   if isinstance(key, Index):                                                        │
# │                                                                                                  │
# │ C:\Users\carga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCac │
# │ he\local-packages\Python38\site-packages\pandas\core\indexes\base.py:5941 in _raise_if_missing   │
# │                                                                                                  │
# │   5938 │   │   │   │   raise KeyError(f"None of [{key}] are in the [{axis_name}]")               │
# │   5939 │   │   │                                                                                 │
# │   5940 │   │   │   not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())       │
# │ ❱ 5941 │   │   │   raise KeyError(f"{not_found} not in index")                                   │
# │   5942 │                                                                                         │
# │   5943 │   @overload                                                                             │
# │   5944 │   def _get_indexer_non_comparable(                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyError: "['index_mesh_lag1', 'index_mesh_lag2', 'index_mesh_lag1_lag2', 'YEAR_CONSTRUCTION_lag1_lag2',
# 'is_fire_lag1_lag2', 'ABOVE_GROUND_FLOORS_lag1_lag2', 'HOUSING_UNITS_lag1_lag2',
# 'distance_to_fire_station_lag1_lag2', 'building_age_lag1_lag2', 'AVERAGE_FAMILY_SIZE_lag1_lag2',
# 'POPULATION_DENSITY_lag1_lag2', '2021_POPULATION_lag1_lag2', 'day_of_week_lag1_lag2', 'INCIDENT_ID_lag1_lag2',
# 'index_mesh_lag3', 'index_mesh_lag1_lag3', 'YEAR_CONSTRUCTION_lag1_lag3', 'is_fire_lag1_lag3',
# 'ABOVE_GROUND_FLOORS_lag1_lag3', 'HOUSING_UNITS_lag1_lag3', 'distance_to_fire_station_lag1_lag3',
# 'building_age_lag1_lag3', 'AVERAGE_FAMILY_SIZE_lag1_lag3', 'POPULATION_DENSITY_lag1_lag3',
# '2021_POPULATION_lag1_lag3', 'day_of_week_lag1_lag3', 'INCIDENT_ID_lag1_lag3', 'index_mesh_lag2_lag3',
# 'YEAR_CONSTRUCTION_lag2_lag3', 'is_fire_lag2_lag3', 'ABOVE_GROUND_FLOORS_lag2_lag3', 'HOUSING_UNITS_lag2_lag3',
# 'distance_to_fire_station_lag2_lag3', 'building_age_lag2_lag3', 'AVERAGE_FAMILY_SIZE_lag2_lag3',
# 'POPULATION_DENSITY_lag2_lag3', '2021_POPULATION_lag2_lag3', 'day_of_week_lag2_lag3', 'INCIDENT_ID_lag2_lag3',
# 'index_mesh_lag1_lag2_lag3', 'YEAR_CONSTRUCTION_lag1_lag2_lag3', 'is_fire_lag1_lag2_lag3',
# 'ABOVE_GROUND_FLOORS_lag1_lag2_lag3', 'HOUSING_UNITS_lag1_lag2_lag3', 'distance_to_fire_station_lag1_lag2_lag3',
# 'building_age_lag1_lag2_lag3', 'AVERAGE_FAMILY_SIZE_lag1_lag2_lag3', 'POPULATION_DENSITY_lag1_lag2_lag3',
# '2021_POPULATION_lag1_lag2_lag3', 'day_of_week_lag1_lag2_lag3', 'INCIDENT_ID_lag1_lag2_lag3'] not in index"
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
merged_aggregated_data.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     grid_lat  grid_long    year  month  index_mesh USE_CATEGORY  \
# 0  45.403963 -73.946646  2005.0    1.0          82      missing
# 1  45.403963 -73.946646  2005.0    2.0          82      missing
# 2  45.403963 -73.946646  2005.0    3.0          82      missing
# 3  45.403963 -73.946646  2005.0    4.0          82      missing
# 4  45.403963 -73.946646  2005.0    5.0          82      missing
#
#    YEAR_CONSTRUCTION  is_fire  ABOVE_GROUND_FLOORS  HOUSING_UNITS  ...  \
# 0                NaN        1                  NaN            NaN  ...
# 1                NaN        0                  NaN            NaN  ...
# 2                NaN        1                  NaN            NaN  ...
# 3                NaN        1                  NaN            NaN  ...
# 4                NaN        0                  NaN            NaN  ...
#
#    HOUSING_UNITS_lag1_lag2_lag3  distance_to_fire_station_lag1_lag2_lag3  \
# 0                           NaN                                      NaN
# 1                           NaN                                      NaN
# 2                           NaN                                      NaN
# 3                           NaN                                      NaN
# 4                           NaN                                      NaN
#
#    building_age_lag1_lag2_lag3  AVERAGE_FAMILY_SIZE_lag1_lag2_lag3  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          NaN                                 NaN
# 3                          NaN                                 NaN
# 4                          NaN                                 NaN
#
#    POPULATION_DENSITY_lag1_lag2_lag3 2021_POPULATION_lag1_lag2_lag3  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   time_of_day_lag1_lag2_lag3  day_of_week_lag1_lag2_lag3  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    INCIDENT_ID_lag1_lag2_lag3 predicted_fire
# 0                         NaN              0
# 1                         NaN              0
# 2                         NaN              0
# 3                         NaN              0
# 4                         NaN              0
#
# [5 rows x 117 columns]

# %%
aggregated_data[['predicted_fire', 'is_fire']].describe()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        predicted_fire        is_fire
# count   593573.000000  593573.000000
# mean         0.192866       0.129649
# std          0.394549       0.335917
# min          0.000000       0.000000
# 25%          0.000000       0.000000
# 50%          0.000000       0.000000
# 75%          0.000000       0.000000
# max          1.000000       1.000000

# %%
aggregated_data['predicted_fire'][aggregated_data['predicted_fire'] == 1].sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 114480

# %%
aggregated_data['is_fire'][aggregated_data['is_fire'] == 1].sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 76956

# %%
selected_month = aggregated_data['month'] == 8
selected_year = aggregated_data['year'] == 2023
fire_prediction_selected_date = aggregated_data[selected_month & selected_year]

# %%
fire_prediction_selected_date.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        grid_lat  grid_long    year  month  index_mesh USE_CATEGORY  \
# 159   45.403963 -73.946646  2023.0    8.0          82      missing
# 345   45.404061 -73.943198  2023.0    8.0          96      missing
# 557   45.404188 -73.950076  2023.0    8.0          68      missing
# 867   45.404592 -73.953471  2023.0    8.0          55      missing
# 1062  45.404897 -73.956301  2023.0    8.0          42      missing
#
#       YEAR_CONSTRUCTION  is_fire  ABOVE_GROUND_FLOORS  HOUSING_UNITS  ...  \
# 159                 NaN        0                  NaN            NaN  ...
# 345                 NaN        0                  NaN            NaN  ...
# 557                 NaN        0                  NaN            NaN  ...
# 867                 NaN        0                  NaN            NaN  ...
# 1062                NaN        0                  NaN            NaN  ...
#
#       HOUSING_UNITS_lag1_lag2_lag3  distance_to_fire_station_lag1_lag2_lag3  \
# 159                            NaN                                      NaN
# 345                            NaN                                 1.615592
# 557                            NaN                                 1.511289
# 867                            NaN                                 1.490979
# 1062                           NaN                                      NaN
#
#       building_age_lag1_lag2_lag3  AVERAGE_FAMILY_SIZE_lag1_lag2_lag3  \
# 159                           NaN                                 NaN
# 345                           NaN                                 NaN
# 557                           NaN                                 NaN
# 867                           NaN                                 NaN
# 1062                          NaN                                 NaN
#
#       POPULATION_DENSITY_lag1_lag2_lag3 2021_POPULATION_lag1_lag2_lag3  \
# 159                                 NaN                            NaN
# 345                                 NaN                            NaN
# 557                                 NaN                            NaN
# 867                                 NaN                            NaN
# 1062                                NaN                            NaN
#
#      time_of_day_lag1_lag2_lag3  day_of_week_lag1_lag2_lag3  \
# 159                         NaN                         NaN
# 345                     morning                         1.0
# 557                     morning                         1.0
# 867                     morning                         3.0
# 1062                        NaN                         NaN
#
#       INCIDENT_ID_lag1_lag2_lag3 predicted_fire
# 159                          NaN              0
# 345                          2.0              0
# 557                          3.0              0
# 867                          1.0              0
# 1062                         NaN              0
#
# [5 rows x 117 columns]

# %%
fire_prediction_selected_date['predicted_fire'][fire_prediction_selected_date['predicted_fire'] == 1].sum()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 462

# %%
# Create a base map of Montreal
montreal_map = folium.Map(location=[45.5017, -73.5673], zoom_start=12)

# Add fire prediction markers to the map
for _, row in fire_prediction.iterrows():
    location = [row['grid_lat'], row['grid_long']]
    is_fire = row['predicted_fire']
    
    if is_fire:
        folium.CircleMarker(
            location=location,
            radius=5,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        ).add_to(montreal_map)
    else:
        folium.CircleMarker(
            location=location,
            radius=5,
            color='blue',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(montreal_map)

# Show map
montreal_map
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <folium.folium.Map object at 0x0000025FA0CDED00>
